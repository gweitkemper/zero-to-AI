# %% [markdown]
# ### Simple "hello world" Jupyter Notebook

# %%
import arrow

utc_time = arrow.utcnow()
print("utc_time is: {}".format(utc_time))
# Out:
# utc_time is: 2026-01-11T13:31:12.306768+00:00
