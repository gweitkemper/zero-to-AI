# %% [markdown]
# ### Simple "hello world" Jupyter Notebook

# %% [markdown]
# # Demonstration Jupyter Notebook for the zero-to-AI series
# # Chris Joakim, 3Cloud
# #
# # This this notebook ....

# %%
# Simple example Cell.  It imports the python "arrow" library and prints the current time.
import arrow
import os

# cwd = current working directory
cwd = os.getcwd()
print(f"current working directory is: {cwd}")

# arrow is a python library for date and time logic
utc_time = arrow.utcnow()
print("utc_time is: {}".format(utc_time))
# Out:
# current working directory is: /Users/cjoakim/github/zero-to-AI-private/python/jupyter
# utc_time is: 2026-01-11T20:19:27.513288+00:00

# %%
import sys

# !{sys.executable} uv pip list
# Out:
# /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/cjoakim/github/zero-to-AI-private/python/jupyter/uv': [Errno 2] No such file or directory

# %%
import os
import pandas as pd

infile = "../data/postal_codes/postal_codes_nc.csv"
infile = "../data/olympics/athlete_events_parsed.csv"
df_olympics = pd.read_csv(infile, sep="|")
print(f"Olympics dataframe shape: {df_olympics.shape}")
print(f"\nFirst few rows:")
print(df_olympics.head())
# Out:
# Olympics dataframe shape: (271116, 16)
#
# First few rows:
#    id                      name sex  age  height  weight            team  noc  \
# 0   1                 A Dijiang   m   24   180.0    80.0           china  chn
# 1   2                  A Lamusi   m   23   170.0    60.0           china  chn
# 2   3       Gunnar Nielsen Aaby   m   24    -1.0    -1.0         denmark  den
# 3   4      Edgar Lindenau Aabye   m   34    -1.0    -1.0  denmark/sweden  den
# 4   5  Christine Jacoba Aaftink   f   21   185.0    82.0     netherlands  ned
#
#          games  year  season       city          sport  \
# 0  1992 summer  1992  summer  barcelona     basketball
# 1  2012 summer  2012  summer     london           judo
# 2  1920 summer  1920  summer  antwerpen       football
# 3  1900 summer  1900  summer      paris     tug-of-war
# 4  1988 winter  1988  winter    calgary  speed skating
#
#                              event medal  medal_value
# ...
